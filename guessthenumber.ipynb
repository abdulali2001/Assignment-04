# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulali2001/Assignment-04/blob/root/guessthenumber.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project** **2**: **Guess** **the** **Number** **Game** **Python** **Project** (**computer**)

# %%
# Project 2 : Guess The Number Game By Computer
# 1 to 100 numbers.

import random

def guess_the_number():
    """Project 2 : Guess The Number Game By Computer."""
    number = random.randint(1, 100)
    guesses_left = 7

    # Welcome message
    print("Welcome to the number guessing game!")
    print("I am thinking of a number between 1 to 100.")

    # Loop generated
    while guesses_left > 0:
        print(f"\nYou have {guesses_left} guesses left.")
        try:
            guess = int(input("Take a guess: "))
        except ValueError:
            print("Invalid input: Please enter a number.")
            continue

        # guess the secret number
        if guess < number:
            print("Too low number . Tell another!")
        elif guess > number:
            print("Too high number . Tell another!")
        else:
            print(f"Congratulations! You got the correct number in {7 - guesses_left + 1} tries.")
            return

        guesses_left -= 1

    # After all guesses are used
    print(f"\nYou ran out of guesses. The number was {number}.")

guess_the_number()
# Out:
# Welcome to the number guessing game!
# I am thinking of a number between 1 to 100.
#
# You have 7 guesses left.
# Take a guess: 13
# Too high number . Tell another!
#
# You have 6 guesses left.
# Take a guess: 25
# Too high number . Tell another!
#
# You have 5 guesses left.
# Take a guess: 38
# Too high number . Tell another!
#
# You have 4 guesses left.
# Take a guess: 46
# Too high number . Tell another!
#
# You have 3 guesses left.
# Take a guess: 74
# Too high number . Tell another!
#
# You have 2 guesses left.
# Take a guess: 59
# Too high number . Tell another!
#
# You have 1 guesses left.
# Take a guess: 63
# Too high number . Tell another!
#
# You ran out of guesses. The number was 12.
