# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulali2001/Assignment-04/blob/root/hangman_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project** **5**: **Hangman** **Python** **Project**

# %%
import random
words = ['enum', 'python', 'colab', 'vscode', 'game']

word =random.choice(words)
guessed_letters = []
attempts = 6

print("welcome to hangman game project 5")
print("_" * len(word))

while attempts > 0:
    guess = input("\n guess the letters: ").lower()

    if len(guess) !=1 or not guess.isalpha():
        print("write one alphabat only!")
        continue
    if guess in guessed_letters:
        print(" this letter is already guess choose another letter")
        continue
    guessed_letters.append(guess)

    if guess in word:
        print("Correct guess! ")
    else:
        attempts -= 1
        print(f"Wrong {attempts} atempts.")

    displayed_word = " ".join([letter if letter in guessed_letters else "_" for letter in word])
    print(displayed_word)

    if "_" not in displayed_word:
        print(f"Congratulation! the correct word is: {word}")
        break

else:
    print(f"Game over! the correct word is: {word}")
# Out:
# welcome to hangman game project 5
# ______
#
#  guess the letters: p
# Correct guess!
# p _ _ _ _ _
#
#  guess the letters: y
# Correct guess!
# p y _ _ _ _
#
#  guess the letters: t
# Correct guess!
# p y t _ _ _
#
#  guess the letters: h
# Correct guess!
# p y t h _ _
#
#  guess the letters: o
# Correct guess!
# p y t h o _
#
#  guess the letters: n
# Correct guess!
# p y t h o n
# Congratulation! the correct word is: python
