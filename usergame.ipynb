# %% [markdown]
# <a href="https://colab.research.google.com/github/abdulali2001/Assignment-04/blob/root/usergame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Project** **3**: **Guess** **the** **Number** **Game** **Python** **Project** (**user**)**bold text**

# %%
import random

def guess_number():
    number_to_guess = random.randint(1, 100)
    guess = 0

    print("Guess the number between 1 and 100!")

    while guess != number_to_guess:
        guess = int(input("Enter your guess number: "))

        if guess < number_to_guess:
            print("Too Low Number!")
        elif guess > number_to_guess:
            print("Too High Number!")
        else:
            print("Congratulations! You got it right!")

guess_number()
# Out:
# Guess the number between 1 and 100!
# Enter your guess number: 50
# Too High Number!
# Enter your guess number: 45
# Too High Number!
# Enter your guess number: 41
# Too High Number!
# Enter your guess number: 29
# Too High Number!
# Enter your guess number: 20
# Too High Number!
# Enter your guess number: 15
# Too High Number!
# Enter your guess number: 6
# Too High Number!
# Enter your guess number: 3
# Congratulations! You got it right!
